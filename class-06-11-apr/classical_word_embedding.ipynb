# %%
from gensim.models import Word2Vec, KeyedVectors
import gensim.downloader as api

# %%
# google news word2vec model

# %%
model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
len(model)
# Out:
# 3000000

# %%
model.most_similar("king", topn=5)
# Out:
# [('kings', 0.7138045430183411),
#  ('queen', 0.6510956883430481),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204220056533813),
#  ('prince', 0.6159993410110474)]

# %%
model.most_similar("man")
# Out:
# [('woman', 0.7664012908935547),
#  ('boy', 0.6824871301651001),
#  ('teenager', 0.6586930155754089),
#  ('teenage_girl', 0.6147903203964233),
#  ('girl', 0.5921714305877686),
#  ('suspected_purse_snatcher', 0.571636438369751),
#  ('robber', 0.5585119128227234),
#  ('Robbery_suspect', 0.5584409832954407),
#  ('teen_ager', 0.5549196600914001),
#  ('men', 0.5489763021469116)]

# %%
model.most_similar("bangalore")
# Out:
# [('chennai', 0.5862480998039246),
#  ('hyderabad', 0.568199872970581),
#  ('delhi', 0.5520831346511841),
#  ('mumbai', 0.5454418659210205),
#  ('pune', 0.542076587677002),
#  ('rahul', 0.5419066548347473),
#  ('kolkata', 0.5386006236076355),
#  ('rajiv', 0.5384308695793152),
#  ('bihar', 0.5341221690177917),
#  ('india', 0.531882643699646)]

# %%
model.similarity("men","women")
# Out:
# 0.7674937

# %%
model.similarity("men","man")
# Out:
# 0.5489763

# %%
model.similarity("men","men")
# Out:
# 1.0
